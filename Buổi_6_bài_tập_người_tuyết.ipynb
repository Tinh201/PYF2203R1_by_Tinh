# %%
import turtle


tl = turtle.Turtle()

screen =tl.getscreen()
screen.bgcolor("black")
#tl.hideturtle()
tl.speed(50)
tl.pencolor("blue")


tl.fillcolor("white")
tl.begin_fill()
tl.pu()
tl.right(90)
tl.forward(210)
tl.left(90)
tl.pendown()
tl.circle(120)
tl.end_fill()

# ve than
tl.pu()
tl.left(90)
tl.forward(120)
tl.pendown()
tl.fillcolor("black")
tl.begin_fill()
tl.circle(10)
tl.end_fill()
tl.pu()
tl.forward(40)
tl.pendown()
tl.fillcolor("orange")
tl.begin_fill()
tl.circle(10)
tl.end_fill()
tl.pu()
tl.forward(35)
tl.pendown()
tl.fillcolor("green")
tl.begin_fill()
tl.circle(10)
tl.end_fill()
tl.pu()
tl.forward(20)
tl.right(90)
tl.backward(20)
tl.pendown()
tl.fillcolor("white")
tl.begin_fill()
tl.circle(80)
tl.end_fill()

# ve mieng
tl.pu()
tl.backward(10)
tl.left(90)
tl.forward(20)
tl.right(90)
tl.pendown()
tl.pensize(3)
tl.circle(20, 90, 100)

# ve mui
tl.pensize(1)
tl.pu()
tl.forward(10)
tl.left(90)
tl.forward(20)
tl.pendown()
tl.fillcolor("yellow")
tl.begin_fill()
tl.forward(45)
tl.right(150)
tl.forward(50)
tl.right(120)
tl.forward(30)
tl.end_fill()           

# ve mat
tl.pu()
tl.backward(60)
tl.right(90)
tl.forward(40)
tl.pendown()
tl.fillcolor("brown")
tl.begin_fill()
tl.circle(10)
tl.end_fill()

tl.pu()
tl.backward(70)
tl.pendown()
tl.fillcolor("brown")
tl.begin_fill()
tl.circle(10)
tl.end_fill()

# ve tay
tl.pensize(5)
tl.pu()
tl.backward(100)
tl.left(90)
tl.forward(130)
tl.left(120)
tl.pendown()
tl.forward(100)
tl.backward(30)
tl.right(60)
tl.forward(20)
tl.backward(20)
tl.left(60)
tl.backward(10)
tl.left(60)
tl.forward(10)

# ve khan
tl.pu()
tl.backward(15)
tl.left(90)
tl.forward(80)
tl.pendown()
tl.pensize(15)
tl.pencolor("red")
tl.forward(140)
tl.left(90)
tl.forward(5)
tl.left(90)
tl.forward(100)
tl.right(90)
tl.forward(50)
tl.left(90)
tl.forward(5)
tl.left(90)
tl.forward(15)
tl.right(90)
tl.forward(9)
tl.left(90)
tl.forward(39)
tl.right(90)
tl.forward(39)

tl.pu()
tl.backward(190)
tl.left(90)
tl.backward(50)
tl.pendown()
tl.pensize(5)
tl.pencolor("blue")
tl.left(60)
tl.forward(100)
tl.backward(30)
tl.right(40)
tl.forward(40)
tl.backward(20)
tl.right(45)
tl.forward(20)
tl.pu()
tl.backward(30)
tl.pendown()
tl.left(120)
tl.forward(20)

# ve mu
tl.pensize(1)
tl.pu()
tl.right(90)
tl.forward(120)
tl.right(90)
tl.forward(120)
tl.pendown()

tl.pensize(30)
tl.pencolor("red")
tl.forward(140)
tl.pensize(1)
tl.left(90)
tl.forward(28)
tl.pu()
tl.left(90)
tl.forward(20)
tl.pendown()
tl.pensize(30)
tl.pencolor("purple")
tl.forward(110)
tl.pensize(5)
tl.pu()
tl.forward(15)
tl.right(90)
tl.forward(13)
tl.pendown()
tl.pencolor("red")
tl.fillcolor("red")
tl.begin_fill()
tl.forward(100)
tl.right(90)
tl.forward(140)
tl.right(90)
tl.forward(100)
tl.right(90)
tl.forward(142)
tl.end_fill()


turtle.done()
